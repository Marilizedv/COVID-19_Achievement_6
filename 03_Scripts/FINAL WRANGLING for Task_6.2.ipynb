# %% [markdown]
# # Task 6.2: Exploring Relationships

# %% [markdown]
# ## This script contains:
# ### Importing libraries & data
# ### Heat map

# %% [markdown]
# # Import Libraries & Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
#create path
path = r'C:\Users\M de Villiers\Desktop\Data Analytics\Achievement 6'

# %%
# import data
df=pd.read_csv(os.path.join(path, '02_Data', 'Prepared_Data', 'monthly_COVID-19_vaccinations_3.csv'), index_col=False)

# %%
df.head()
# Out:
#        country  Population (2020) iso_code month_year  \
# 0  Afghanistan           39074280      AFG    2021-02
# 1  Afghanistan           39074280      AFG    2021-03
# 2  Afghanistan           39074280      AFG    2021-04
# 3  Afghanistan           39074280      AFG    2021-05
# 4  Afghanistan           39074280      AFG    2021-06
#
#                                             vaccines  total_vaccinations  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...              8200.0
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...             54000.0
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            240000.0
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            600152.0
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            886854.0
#
#    people_vaccinated  people_fully_vaccinated  monthly_vaccinations_raw  \
# 0             8200.0                      0.0                       0.0
# ...

# %%
# check missing values
df.isnull().sum()
# Out:
# country                                 0
# Population (2020)                       0
# iso_code                               22
# month_year                             22
# vaccines                               22
# total_vaccinations                     22
# people_vaccinated                      22
# people_fully_vaccinated                22
# monthly_vaccinations_raw               22
# monthly_vaccinations                   22
# total_vaccinations_per_hundred         22
# people_vaccinated_per_hundred          22
# people_fully_vaccinated_per_hundred    22
# monthly_vaccinations_per_million       22
# dtype: int64

# %%
# create df of missing values
df_nan2 = df[df['month_year'].isnull() == True]

# %%
df_nan2
# Out:
#                        country  Population (2020) iso_code month_year  \
# 44              American Samoa              55169      NaN        NaN
# 526            Channel Islands             174140      NaN        NaN
# 841                    Eritrea            3554797      NaN        NaN
# 943              French Guiana             299958      NaN        NaN
# 1085                Guadeloupe             400136      NaN        NaN
# 1086                      Guam             169031      NaN        NaN
# 1162                  Holy See                801      NaN        NaN
# 1695          Marshall Islands              59259      NaN        NaN
# 1696                Martinique             375213      NaN        NaN
# 1725                   Mayotte             273905      NaN        NaN
# 1742                Micronesia             115231      NaN        NaN
# 1977               North Korea           25798588      NaN        NaN
# ...

# %%
# create new df without missing values
df1 = df[df['month_year'].isnull() == False]

# %%
df1.head()
# Out:
#        country  Population (2020) iso_code month_year  \
# 0  Afghanistan           39074280      AFG    2021-02
# 1  Afghanistan           39074280      AFG    2021-03
# 2  Afghanistan           39074280      AFG    2021-04
# 3  Afghanistan           39074280      AFG    2021-05
# 4  Afghanistan           39074280      AFG    2021-06
#
#                                             vaccines  total_vaccinations  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...              8200.0
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...             54000.0
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            240000.0
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            600152.0
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...            886854.0
#
#    people_vaccinated  people_fully_vaccinated  monthly_vaccinations_raw  \
# 0             8200.0                      0.0                       0.0
# ...

# %%
df1.tail()
# Out:
#        country  Population (2020) iso_code month_year  \
# 2983  Zimbabwe           14899771      ZWE    2021-11
# 2984  Zimbabwe           14899771      ZWE    2021-12
# 2985  Zimbabwe           14899771      ZWE    2022-01
# 2986  Zimbabwe           14899771      ZWE    2022-02
# 2987  Zimbabwe           14899771      ZWE    2022-03
#
#                                                vaccines  total_vaccinations  \
# 2983  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...           6611942.0
# 2984  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...           7264791.0
# 2985  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...           7632514.0
# 2986  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...           7890951.0
# 2987  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...           7943325.0
#
#       people_vaccinated  people_fully_vaccinated  monthly_vaccinations_raw  \
# 2983          3795401.0                2816541.0                  618042.0
# ...

# %%
df1.shape
# Out:
# (2966, 14)

# %%
df1.to_csv(os.path.join(path, '02_Data', 'Prepared_Data', 'monthly_COVID-19_vaccinations_6.csv'), index=False)
